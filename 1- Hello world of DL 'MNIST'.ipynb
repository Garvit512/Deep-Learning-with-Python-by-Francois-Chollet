# %% [markdown]
# Created by: Garvit Kumar Arya\
# Date: 6 July 2020

# %%
# %%capture
pip install ipython-autotime

# %%
# %load_ext autotime
# Out:
# time: 76.4 µs (started: 2021-04-11 20:10:01 +00:00)

# %% [markdown]
# **Loading Dataset**

# %%
import matplotlib.pyplot as plt
# Out:
# time: 1.21 ms (started: 2021-04-11 20:10:01 +00:00)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# time: 1.83 s (started: 2021-04-11 20:10:01 +00:00)

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)
# time: 1.21 ms (started: 2021-04-11 20:10:03 +00:00)

# %%
print(len(train_labels))
# Out:
# 60000
# time: 1.64 ms (started: 2021-04-11 20:10:03 +00:00)

# %%
print(train_labels)
# Out:
# [5 0 4 ... 5 6 8]
# time: 2.44 ms (started: 2021-04-11 20:10:03 +00:00)

# %% [markdown]
# **Preparing the image data**

# %%
train_images.shape
# Out:
# (60000, 28, 28)
# time: 8.57 ms (started: 2021-04-11 20:10:12 +00:00)

# %%
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32') / 255
# Out:
# time: 77.2 ms (started: 2021-04-11 20:12:40 +00:00)

# %% [markdown]
#  **Preparing the labels**

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# time: 4.07 ms (started: 2021-04-11 20:12:46 +00:00)

# %% [markdown]
# **Architecture**

# %%
from keras import models
from keras import layers
from keras.optimizers import Adam

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28, )))
network.add(layers.Dense(10, activation='softmax'))
# Out:
# time: 5.42 s (started: 2021-04-11 20:13:03 +00:00)

# %% [markdown]
#  **The compilation step**

# %%
network.compile(optimizer=Adam(learning_rate=0.01),
                loss = 'categorical_crossentropy',
                metrics = ['accuracy']
               )
# Out:
# time: 16.4 ms (started: 2021-04-11 20:13:21 +00:00)

# %% [markdown]
# **Training**

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0638 - accuracy: 0.9823
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0650 - accuracy: 0.9829
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0575 - accuracy: 0.9842
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0593 - accuracy: 0.9851
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0517 - accuracy: 0.9862
# time: 5.34 s (started: 2021-04-11 20:13:35 +00:00)

# %% [markdown]
# **Evaluating test data**

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
test_acc
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1750 - accuracy: 0.9741
# 0.9740999937057495
# time: 689 ms (started: 2021-04-11 20:31:43 +00:00)
